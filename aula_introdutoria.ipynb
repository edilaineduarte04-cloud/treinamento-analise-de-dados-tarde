# %%
print("Treinamento de IA para Análise de Dados")
# Out:
# Treinamento de IA para Análise de Dados

# %%
print("Edilaine")
# Out:
# Edilaine

# %%
nome = "Fabio Moreno"
idade = 39
email = "fabio.moreno@gmail.com"
profissao = "desenvolvedor de sistemas"

# %%
print (nome)
print (idade)
print (email)
print (profissao)
# Out:
# Fabio Moreno
# 39
# fabio.moreno@gmail.com
# desenvolvedor de sistemas

# %%
print(profissao)
# Out:
# desenvolvedor de sistemas

# %%
print (profissao)
# Out:
# desenvolvedor de sistemas

# %%
# COMPARADORES
print (10>5)
# Out:
# True

# %%
comparador = 10 > 5 # Retorna se true for maior
print (comparador)
# Out:
# True

# %%
Comparador  = 10 < 5 # Retorna True se for menor
print (comparador)
# Out:
# True

# %%
comparador = (10 == 10) # Retorna TRUE se forem iguais
print (comparador)
# Out:
# True

# %%
comparador = (10 != 5) #Retorna True se forem diferentes
print (comparador)
# Out:
# True

# %%
temperatura = 100
if temperatura > 100: 
    print("ALARME! O MOTOR ESTÁ FERVENDO!")
else:
    print("MOTOR EM TEMPERATURA IDEAL")
# Out:
# MOTOR EM TEMPERATURA IDEAL

# %%
uniforme = 40
#Power bi = 32
#Ia e Analise de Dados = 32
#Eletricista Instalador = 160

if uniforme > 42:
    print ("Obrigatório uso de uniforme")
else:
    print ("Não é necessário usar o uniforme, somente o crachá")
# Out:
# Não é necessário usar o uniforme, somente o crachá

# %%
# O comando Input solicita a interação do usuário
nota = int(input("Digite a sua note"))
print (nota)
# Out:
# 10

# %%
if nota > 9:
    print ("Nota Excelente")
elif nota > 7:
    print ("Nota Boa")
elif nota > 5:
    print ("Nota Regular")
else:
    print ("Reprovado")
# Out:
# Nota Excelente

# %%
# APP de um banco virtual
nome_primario = input("Digite o seu nome_primario: ")
print (f"Bem vinda, {nome_primario}")
# Out:
# Bem vinda, Edilaine

# %%
idade = int(input ("Digite a sua idade"))
print (idade)
print (type(idade))
# Out:
# 30
# <class 'int'>
