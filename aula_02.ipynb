# %%
# Estruturas de Dados
temperaturas = [30, 35, 39, 40, 42,45, 38, 37]
print (temperaturas)
# Out:
# [30, 35, 39, 40, 42, 45, 38, 37]

# %%
print (temperaturas [0])
# Out:
# 30

# %%
print (temperaturas [1])
# Out:
# 35

# %%
print (f"O primeiro registro de temperatura foi de {temperaturas [0]} graus")
# Out:
# O primeiro registro de temperatura foi de 30 graus

# %%
temperaturas [0] = 35
print (temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37]

# %%
print (f"O primeiro registro de temperatura foi de {temperaturas [0]} graus")
# Out:
# O primeiro registro de temperatura foi de 35 graus

# %%
temperaturas.append(50)
print (temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove (39)
print (temperaturas)
# Out:
# [35, 35, 40, 42, 45, 38, 37, 50]

# %% [markdown]
# # Criem uma lista de compras e solicitem que o usuário insira informações (3 comandos input). Exibir a lista de compras.

# %%
informacoes = []
info1 = input ("Digite a primeira infomação")
info2 = input ("Digite a segunda informação")
info3 = input ("Digite a terceira informação")
informacoes.append (info1)
informacoes.append (info2)
informacoes.append (info3)
print (informacoes)
# Out:
# ['Maçã', 'Laranja', 'Abacaxi']
